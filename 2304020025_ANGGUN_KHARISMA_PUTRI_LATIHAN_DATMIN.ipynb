# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Load data
df = pd.read_excel("DATAAAAA LATIHAN.xlsx")

# Cek data
print(df.head())
# Out:
#    siswa  nilai
# 0      1     67
# 1      2     61
# 2      3     74
# 3      4     71
# 4      5     70

# %%
X = df[['nilai']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Metode Elbow')
plt.xlabel('Jumlah Cluster')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

print(df.head())
# Out:
#    siswa  nilai  cluster
# 0      1     67        2
# 1      2     61        0
# 2      3     74        1
# 3      4     71        1
# 4      5     70        1

# %%
plt.scatter(df.index, df['nilai'], c=df['cluster'], cmap='viridis')
plt.title('Hasil Clustering Nilai Siswa')
plt.xlabel('Index Siswa')
plt.ylabel('Nilai')
plt.show()

# %%
print(df.groupby('cluster')['nilai'].mean())
# Out:
# cluster
# 0    63.334585
# 1    71.992000
# 2    67.440547
# Name: nilai, dtype: float64
